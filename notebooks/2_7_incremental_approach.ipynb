# %%
import requests
from bs4 import BeautifulSoup

url = "https://gihyo.jp/list/article"

res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

titles = soup.find_all("p", class_="m-listitem__title")
for title in titles:
    print(title.text.strip())
# Out:
# さくらインターネット、生成AI向けクラウドサービスを2024年に開始へ
# まつもとゆきひろさん「30 Years of Ruby」
# 〜RubyKaigi 2023 1日目キーノート
# 第78回Perl Webアプリケーションのリプレイスで大事なこと
# ～Stranglerパターンで段階的に移行する（1）
# Web3の新時代を拓くココネのエンジニアリング力を探る
# 人気の着せ替えアプリにWeb3要素を追加
# 『project Sunbeam』、Ubuntu 23.10（mantic）の開発/タイリングアシスタントの追加、Ubuntu 22.10（kinetic）のEOL
# Web3の新時代を拓くココネのエンジニアリング力を探る
# 誰もが知るじゃんけんに戦略性とNFTを盛り込みグローバル展開
# Tap to Pay on Androidの試用プログラムが開始
# Adobe IllustratorにFireflyを統合、対話型AIによる色変換機能「Generative Recolor」を搭載へ
# 第767回Debian 12 "Bookworm"の紹介
# Bullmqを使ったジョブキューの実装
# メモリプロファイラ「Memray」の解説
# HashiCorp、Terraform 1.5をリリース
# データの活用
# ～活用パターンにもとづく、AWSソリューションの選択肢
# Web3の新時代を拓くココネのエンジニアリング力を探る
# クライアントエンジニアからサーバエンジニアへの挑戦
# Blenderの機能、モディファイアの1つ「ブーリアン」と複数の頂点を同時に動かす方法を見てみよう
# Ubuntuにおける2038年問題との戦い・暗号化設定の調整、SmartNICとUbuntu
# “ia32_disabled”な世界へ ―SUSEエンジニア、オプションで32ビットサポートを無効化するパッチを提案
# 10月開催「PyCon APAC 2023」スポンサー募集中
# データエンジニアが最初に学ぶべき3つのポイント：「ETL」「データモデリング」「ワークフロー」
# Red Hat、RHELからLibreOfficeパッケージを削除へ、今後はFlatpakで対応
# 2023年6月版 New Android Features、発表
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://gihyo.jp/list/article"

res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

items = soup.find_all("div", class_="m-listitem__wrapper")
for item in items:
    title = item.find("p", class_="m-listitem__title").text.strip()
    author = item.find("p", class_="m-listitem__author").text.strip()
    status = item.find("p", class_="m-listitem__status").text.strip()
    print("Title:", title)
    print("Author:", author)
    print("Status:", status)
    print()
# Out:
# Title: さくらインターネット、生成AI向けクラウドサービスを2024年に開始へ
# Author:
# Status: 2023-06-19
#
# Title: まつもとゆきひろさん「30 Years of Ruby」
# 〜RubyKaigi 2023 1日目キーノート
# Author: 伊藤遼
# Status: 2023-06-19
#
# Title: 第78回Perl Webアプリケーションのリプレイスで大事なこと
# ～Stranglerパターンで段階的に移行する（1）
# Author: 須藤将史［著］，牧大輔，福本貴之，松木雅幸，大沢和宏［監修］
# Status: 2023-06-19
#
# Title: Web3の新時代を拓くココネのエンジニアリング力を探る
# 人気の着せ替えアプリにWeb3要素を追加
# Author: 編集部
# Status: 広告・宣伝2023-06-19
#
# Title: 『project Sunbeam』、Ubuntu 23.10（mantic）の開発/タイリングアシスタントの追加、Ubuntu 22.10（kinetic）のEOL
# Author: 吉田史
# Status: 2023-06-16
#
# Title: Web3の新時代を拓くココネのエンジニアリング力を探る
# 誰もが知るじゃんけんに戦略性とNFTを盛り込みグローバル展開
# Author: 編集部
# Status: 広告・宣伝2023-06-15
#
# Title: Tap to Pay on Androidの試用プログラムが開始
# Author: 傍島康雄
# Status: 2023-06-15
#
# Title: Adobe IllustratorにFireflyを統合、対話型AIによる色変換機能「Generative Recolor」を搭載へ
# Author:
# Status: 2023-06-15
#
# Title: 第767回Debian 12 "Bookworm"の紹介
# Author: 佐々木洋平
# Status: 2023-06-14
#
# Title: Bullmqを使ったジョブキューの実装
# Author: しゅいろ
# Status: 2023-06-14
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://gihyo.jp/list/article"

res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

titles = []
authors = []
statuses = []

items = soup.find_all("div", class_="m-listitem__wrapper")
for item in items:
    title = item.find("p", class_="m-listitem__title").text.strip()
    author = item.find("p", class_="m-listitem__author").text.strip()
    status = item.find("p", class_="m-listitem__status").text.strip()
    titles.append(title)
    authors.append(author)
    statuses.append(status)

df = pd.DataFrame({
    "Title": titles,
    "Author": authors,
    "Status": statuses
})

print(df)
# Out:
#                                                 Title  \
# 0                 さくらインターネット、生成AI向けクラウドサービスを2024年に開始へ
# 1   まつもとゆきひろさん「30 Years of Ruby」 \n〜RubyKaigi 2023...
# 2   第78回Perl Webアプリケーションのリプレイスで大事なこと \n～Stranglerパ...
# 3   Web3の新時代を拓くココネのエンジニアリング力を探る\n人気の着せ替えアプリにWeb3要素を追加
# 4   『project Sunbeam』、Ubuntu 23.10（mantic）の開発/タイリン...
# 5   Web3の新時代を拓くココネのエンジニアリング力を探る\n誰もが知るじゃんけんに戦略性とNF...
# 6                    Tap to Pay on Androidの試用プログラムが開始
# 7   Adobe IllustratorにFireflyを統合、対話型AIによる色変換機能「Gen...
# 8                        第767回Debian 12 "Bookworm"の紹介
# 9                                 Bullmqを使ったジョブキューの実装
# 10                               メモリプロファイラ「Memray」の解説
# 11                       HashiCorp、Terraform 1.5をリリース
# 12               データの活用 \n～活用パターンにもとづく、AWSソリューションの選択肢
# 13  Web3の新時代を拓くココネのエンジニアリング力を探る\nクライアントエンジニアからサーバエ...
# 14  Blenderの機能、モディファイアの1つ「ブーリアン」と複数の頂点を同時に動かす方法を見てみよう
# 15     Ubuntuにおける2038年問題との戦い・暗号化設定の調整、SmartNICとUbuntu
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

url = "https://gihyo.jp/list/article"

res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

titles = []
authors = []
statuses = []

items = soup.find_all("div", class_="m-listitem__wrapper")
for item in items:
    title = item.find("p", class_="m-listitem__title").text.strip()
    author = item.find("p", class_="m-listitem__author").text.strip()
    status = item.find("p", class_="m-listitem__status").text.strip()
    # 正規表現で日付だけを抽出してYYYY-MM-DD形式に変換する
    date_match = re.search(r'\d{4}-\d{2}-\d{2}', status)
    if date_match:
        status = date_match.group(0)
    else:
        status = ""
    titles.append(title)
    authors.append(author)
    statuses.append(status)

df = pd.DataFrame({
    "Title": titles,
    "Author": authors,
    "Status": statuses
})

print(df)
# Out:
#                                                 Title  \
# 0                 さくらインターネット、生成AI向けクラウドサービスを2024年に開始へ
# 1   まつもとゆきひろさん「30 Years of Ruby」 \n〜RubyKaigi 2023...
# 2   第78回Perl Webアプリケーションのリプレイスで大事なこと \n～Stranglerパ...
# 3   Web3の新時代を拓くココネのエンジニアリング力を探る\n人気の着せ替えアプリにWeb3要素を追加
# 4   『project Sunbeam』、Ubuntu 23.10（mantic）の開発/タイリン...
# 5   Web3の新時代を拓くココネのエンジニアリング力を探る\n誰もが知るじゃんけんに戦略性とNF...
# 6                    Tap to Pay on Androidの試用プログラムが開始
# 7   Adobe IllustratorにFireflyを統合、対話型AIによる色変換機能「Gen...
# 8                        第767回Debian 12 "Bookworm"の紹介
# 9                                 Bullmqを使ったジョブキューの実装
# 10                               メモリプロファイラ「Memray」の解説
# 11                       HashiCorp、Terraform 1.5をリリース
# 12               データの活用 \n～活用パターンにもとづく、AWSソリューションの選択肢
# 13  Web3の新時代を拓くココネのエンジニアリング力を探る\nクライアントエンジニアからサーバエ...
# 14  Blenderの機能、モディファイアの1つ「ブーリアン」と複数の頂点を同時に動かす方法を見てみよう
# 15     Ubuntuにおける2038年問題との戦い・暗号化設定の調整、SmartNICとUbuntu
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

url = "https://gihyo.jp/list/article"

res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")

titles = []
authors = []
statuses = []

items = soup.find_all("div", class_="m-listitem__wrapper")
for item in items:
    title = item.find("p", class_="m-listitem__title").text.strip()
    author = item.find("p", class_="m-listitem__author").text.strip()
    status = item.find("p", class_="m-listitem__status").text.strip()
    # 正規表現で日付だけを抽出してYYYY-MM-DD形式に変換する
    date_match = re.search(r'\d{4}-\d{2}-\d{2}', status)
    if date_match:
        status = date_match.group(0)
    else:
        status = ""
    titles.append(title)
    authors.append(author)
    statuses.append(status)

df = pd.DataFrame({
    "Title": titles,
    "Author": authors,
    "Status": statuses
})

print(df)
# データフレームをCSVファイルに出力する
df.to_csv("gihyo_list.csv", index=False)
# Out:
#                                                 Title  \
# 0                 さくらインターネット、生成AI向けクラウドサービスを2024年に開始へ
# 1   まつもとゆきひろさん「30 Years of Ruby」 \n〜RubyKaigi 2023...
# 2   第78回Perl Webアプリケーションのリプレイスで大事なこと \n～Stranglerパ...
# 3   Web3の新時代を拓くココネのエンジニアリング力を探る\n人気の着せ替えアプリにWeb3要素を追加
# 4   『project Sunbeam』、Ubuntu 23.10（mantic）の開発/タイリン...
# 5   Web3の新時代を拓くココネのエンジニアリング力を探る\n誰もが知るじゃんけんに戦略性とNF...
# 6                    Tap to Pay on Androidの試用プログラムが開始
# 7   Adobe IllustratorにFireflyを統合、対話型AIによる色変換機能「Gen...
# 8                        第767回Debian 12 "Bookworm"の紹介
# 9                                 Bullmqを使ったジョブキューの実装
# 10                               メモリプロファイラ「Memray」の解説
# 11                       HashiCorp、Terraform 1.5をリリース
# 12               データの活用 \n～活用パターンにもとづく、AWSソリューションの選択肢
# 13  Web3の新時代を拓くココネのエンジニアリング力を探る\nクライアントエンジニアからサーバエ...
# 14  Blenderの機能、モディファイアの1つ「ブーリアン」と複数の頂点を同時に動かす方法を見てみよう
# 15     Ubuntuにおける2038年問題との戦い・暗号化設定の調整、SmartNICとUbuntu
# ...
